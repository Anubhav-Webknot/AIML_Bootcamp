# %% [markdown]
# <a href="https://colab.research.google.com/github/Anubhav-Webknot/Aiml-assignment-1/blob/main/Day1_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_csv('./tripadvisor_hotel_reviews.csv')

# %% [markdown]
# Viewing the dataset

# %%
df
# Out:
#                                                   Review  Rating
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      unique, great stay, wonderful time hotel monac...       5
# 4      great stay great stay, went seahawk game aweso...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2
#
# [20491 rows x 2 columns]

# %% [markdown]
# First 5 values

# %%
df.head(5)
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %% [markdown]
# Display last 5 values

# %%
df.tail(5)
# Out:
#                                                   Review  Rating
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2

# %% [markdown]
#  labels 'positive' for rating value > 3 and 'negative' for <= 3

# %%
df1=pd.read_csv('./tripadvisor_hotel_reviews.csv')
df1['Rating Label']=np.where(df1['Rating']>3,'Positive','Negative')
df1
# Out:
#                                                   Review  Rating Rating Label
# 0      nice hotel expensive parking got good deal sta...       4     Positive
# 1      ok nothing special charge diamond member hilto...       2     Negative
# 2      nice rooms not 4* experience hotel monaco seat...       3     Negative
# 3      unique, great stay, wonderful time hotel monac...       5     Positive
# 4      great stay great stay, went seahawk game aweso...       5     Positive
# ...                                                  ...     ...          ...
# 20486  best kept secret 3rd time staying charm, not 5...       5     Positive
# 20487  great location price view hotel great quick pl...       4     Positive
# 20488  ok just looks nice modern outside, desk staff ...       2     Negative
# 20489  hotel theft ruined vacation hotel opened sept ...       1     Negative
# 20490  people talking, ca n't believe excellent ratin...       2     Negative
#
# [20491 rows x 3 columns]

# %% [markdown]
# labels '1' for rating value > 3 and '0' for <= 3

# %%
df1['Binary Rating Label']=np.where(df1['Rating']>3,'1','0')
df1
# Out:
#                                                   Review  Rating Rating Label  \
# 0      nice hotel expensive parking got good deal sta...       4     Positive
# 1      ok nothing special charge diamond member hilto...       2     Negative
# 2      nice rooms not 4* experience hotel monaco seat...       3     Negative
# 3      unique, great stay, wonderful time hotel monac...       5     Positive
# 4      great stay great stay, went seahawk game aweso...       5     Positive
# ...                                                  ...     ...          ...
# 20486  best kept secret 3rd time staying charm, not 5...       5     Positive
# 20487  great location price view hotel great quick pl...       4     Positive
# 20488  ok just looks nice modern outside, desk staff ...       2     Negative
# 20489  hotel theft ruined vacation hotel opened sept ...       1     Negative
# 20490  people talking, ca n't believe excellent ratin...       2     Negative
#
#       Binary Rating Label
# ...

# %% [markdown]
# Calculate the lengths of each record in 'review' column and add to the dataframe

# %%
df['Review_Length'] = df['Review'].apply(len)
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      unique, great stay, wonderful time hotel monac...       5
# 4      great stay great stay, went seahawk game aweso...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2
#
#        Review_Length
# 0                593
# 1               1689
# 2               1427
# 3                600
# 4               1281
# ...              ...
# 20486            733
# ...

# %% [markdown]
# Calculate the number of words in 'review' column and add to the dataframe

# %%
df['Word_Count'] = df['Review'].apply(lambda x: len(x.split()))

# %%
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      unique, great stay, wonderful time hotel monac...       5
# 4      great stay great stay, went seahawk game aweso...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2
#
#        Review_Length  Word_Count
# 0                593          87
# 1               1689         250
# 2               1427         217
# 3                600          89
# ...

# %% [markdown]
# Calculate the average length of word for each record in 'review' column and add to the dataframe

# %%
df['Avg_Word_Length'] = df.apply(lambda row: row['Review_Length'] / row['Word_Count'], axis=1)
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      unique, great stay, wonderful time hotel monac...       5
# 4      great stay great stay, went seahawk game aweso...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2
#
#        Review_Length  Word_Count  Avg_Word_Length
# 0                593          87         6.816092
# 1               1689         250         6.756000
# ...

# %% [markdown]
# Calculate the average sentence length of the sentences in the 'review' and add to the dataframe

# %%
df['Sentence_Count'] = df['Review'].apply(lambda x: x.count("."))
df['Avg_Sentence_Length'] = df['Word_Count'] / (df['Sentence_Count'] + 1)
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      unique, great stay, wonderful time hotel monac...       5
# 4      great stay great stay, went seahawk game aweso...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2
#
#        Review_Length  Word_Count  Avg_Word_Length  Sentence_Count  \
# 0                593          87         6.816092               0
# ...

# %% [markdown]
# Visualise each of the columns with respect to the 'Rating' column

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Rating'], df['Review_Length'])
plt.title('Review Length vs Rating')
plt.xlabel('Rating')
plt.ylabel('Review Length')
plt.show()

plt.scatter(df['Rating'], df['Word_Count'],color='y')
plt.title('Word_Count vs Rating')
plt.xlabel('Rating')
plt.ylabel('Word_Count')
plt.show()

plt.scatter(df['Rating'], df['Avg_Word_Length'],color='g')
plt.title('Avg_Word_Length vs Rating')
plt.xlabel('Rating')
plt.ylabel('Avg_Word_Length')
plt.show()

plt.scatter(df['Rating'], df['Sentence_Count'],color='b')
plt.title('Sentence_Count vs Rating')
plt.xlabel('Rating')
plt.ylabel('Sentence_Count')
plt.show()

plt.scatter(df['Rating'], df['Avg_Sentence_Length'],color='r')
plt.title('Avg_Sentence_Length vs Rating')
plt.xlabel('Rating')
plt.ylabel('Avg_Sentence_Length')
plt.show()

# %% [markdown]
#  Preprocess review  to lowercase

# %%
df['Review'] = df['Review'].apply(lambda x: x.lower())
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4* experience hotel monaco seat...       3
# 3      unique, great stay, wonderful time hotel monac...       5
# 4      great stay great stay, went seahawk game aweso...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm, not 5...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside, desk staff ...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking, ca n't believe excellent ratin...       2
#
#        Review_Length  Word_Count  Avg_Word_Length  Sentence_Count  \
# 0                593          87         6.816092               0
# ...

# %% [markdown]
#  Remove punctuations

# %%
import string
from nltk.corpus import stopwords

df['Review'] = df['Review'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms not 4 experience hotel monaco seatt...       3
# 3      unique great stay wonderful time hotel monaco ...       5
# 4      great stay great stay went seahawk game awesom...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm not 5s...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok just looks nice modern outside desk staff n...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking ca nt believe excellent ratings...       2
#
#        Review_Length  Word_Count  Avg_Word_Length  Sentence_Count  \
# 0                593          87         6.816092               0
# ...

# %% [markdown]
# Stopwords

# %%
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
df['Review'] = df['Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
df
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms 4 experience hotel monaco seattle g...       3
# 3      unique great stay wonderful time hotel monaco ...       5
# 4      great stay great stay went seahawk game awesom...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm 5star ...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok looks nice modern outside desk staff nt par...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking ca nt believe excellent ratings...       2
#
#        Review_Length  Word_Count  Avg_Word_Length  Sentence_Count  \
# ...

# %% [markdown]
# Store the text in the 'review' column in a form list

# %%
df['Review_Lists'] = df['Review'].apply(lambda x: x.split())
df
# Out:
#                                                   Review  Rating  \
# 0      nice hotel expensive parking got good deal sta...       4
# 1      ok nothing special charge diamond member hilto...       2
# 2      nice rooms 4 experience hotel monaco seattle g...       3
# 3      unique great stay wonderful time hotel monaco ...       5
# 4      great stay great stay went seahawk game awesom...       5
# ...                                                  ...     ...
# 20486  best kept secret 3rd time staying charm 5star ...       5
# 20487  great location price view hotel great quick pl...       4
# 20488  ok looks nice modern outside desk staff nt par...       2
# 20489  hotel theft ruined vacation hotel opened sept ...       1
# 20490  people talking ca nt believe excellent ratings...       2
#
#        Review_Length  Word_Count  Avg_Word_Length  Sentence_Count  \
# 0                593          87         6.816092               0
# ...

# %% [markdown]
# Identify most common words using 'Review_lists' column

# %%
import nltk
from nltk import FreqDist
all_words = [word for sublist in df['Review_Lists'] for word in sublist]
freq_dist=FreqDist(all_words)
freq_dist.most_common(10)
# Out:
# [('hotel', 48832),
#  ('room', 34300),
#  ('great', 21087),
#  ('nt', 18989),
#  ('good', 16972),
#  ('staff', 16203),
#  ('stay', 15153),
#  ('nice', 12399),
#  ('rooms', 12015),
#  ('location', 11032)]

# %% [markdown]
# Plot the most commonly occuring words

# %%
plt.figure(figsize=(10, 6))
freq_dist.plot(5, cumulative=False)

plt.show()
